# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read data and save to DataFrame

# %%
dfDate22=pd.read_csv('22_2_2023.csv')
dfDate23=pd.read_csv('23_2_2023.csv')
dfDate24=pd.read_csv('24_2_2023.csv')
dfDate22
# Out:
#      Unnamed: 0    Country, Other  Total Cases New Cases Total Deaths  \
# 0             0             China      503,302       NaN        5,272
# 1             1               USA  105,148,929   +24,941    1,144,242
# 2             2             India   44,685,450      +193      530,763
# 3             3            France   39,600,548    +4,584      164,829
# 4             4           Germany   38,068,912   +25,038      167,604
# ..          ...               ...          ...       ...          ...
# 226         226  Diamond Princess          712       NaN           13
# 227         227      Vatican City           29       NaN          NaN
# 228         228    Western Sahara           10       NaN            1
# 229         229        MS Zaandam            9       NaN            2
# 230         230           Tokelau            5       NaN          NaN
#
#      New Deaths Total Recovered New Recovered Active Cases Serious, Critical  \
# 0           NaN         379,053           NaN      118,977             7,557
# 1         249.0     102,473,264       +58,247    1,531,423             2,436
# 2           1.0      44,152,687          +127        2,000               NaN
# 3          38.0      39,368,047        +3,989       67,672               869
# 4         113.0      37,630,800       +13,600      270,508               NaN
# ..          ...             ...           ...          ...               ...
# 226         NaN             699           NaN            0               NaN
# 227         NaN              29           NaN            0               NaN
# 228         NaN               9           NaN            0               NaN
# 229         NaN               7           NaN            0               NaN
# 230         NaN             NaN           NaN            5               NaN
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0                 347              4    160,000,000       110,461
# 1             314,060          3,418  1,163,631,220     3,475,546
# 2              31,768            377    918,101,478       652,695
# 3             603,809          2,513    271,490,188     4,139,547
# 4             453,830          1,998    122,332,384     1,458,359
# ..                ...            ...            ...           ...
# 226               NaN            NaN            NaN           NaN
# 227            36,295            NaN            NaN           NaN
# 228                16              2            NaN           NaN
# 229               NaN            NaN            NaN           NaN
# 230             3,628            NaN            NaN           NaN
#
#         Population          Continent
# 0    1,448,471,400               Asia
# 1      334,805,269      North America
# 2    1,406,631,776               Asia
# 3       65,584,518             Europe
# 4       83,883,596             Europe
# ..             ...                ...
# 226            NaN                NaN
# 227            799             Europe
# 228        626,161             Africa
# 229            NaN                NaN
# 230          1,378  Australia/Oceania
#
# [231 rows x 16 columns]

# %% [markdown]
# ### Drop first column

# %%
dfDate22 = dfDate22.drop('Unnamed: 0', axis = 1)
dfDate23 = dfDate23.drop('Unnamed: 0', axis = 1)
dfDate24 = dfDate24.drop('Unnamed: 0', axis = 1)

# %%
dfDate22
# Out:
#        Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# 0               China      503,302       NaN        5,272         NaN
# 1                 USA  105,148,929   +24,941    1,144,242       249.0
# 2               India   44,685,450      +193      530,763         1.0
# 3              France   39,600,548    +4,584      164,829        38.0
# 4             Germany   38,068,912   +25,038      167,604       113.0
# ..                ...          ...       ...          ...         ...
# 226  Diamond Princess          712       NaN           13         NaN
# 227      Vatican City           29       NaN          NaN         NaN
# 228    Western Sahara           10       NaN            1         NaN
# 229        MS Zaandam            9       NaN            2         NaN
# 230           Tokelau            5       NaN          NaN         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0           379,053           NaN      118,977             7,557
# 1       102,473,264       +58,247    1,531,423             2,436
# 2        44,152,687          +127        2,000               NaN
# 3        39,368,047        +3,989       67,672               869
# 4        37,630,800       +13,600      270,508               NaN
# ..              ...           ...          ...               ...
# 226             699           NaN            0               NaN
# 227              29           NaN            0               NaN
# 228               9           NaN            0               NaN
# 229               7           NaN            0               NaN
# 230             NaN           NaN            5               NaN
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0                 347              4    160,000,000       110,461
# 1             314,060          3,418  1,163,631,220     3,475,546
# 2              31,768            377    918,101,478       652,695
# 3             603,809          2,513    271,490,188     4,139,547
# 4             453,830          1,998    122,332,384     1,458,359
# ..                ...            ...            ...           ...
# 226               NaN            NaN            NaN           NaN
# 227            36,295            NaN            NaN           NaN
# 228                16              2            NaN           NaN
# 229               NaN            NaN            NaN           NaN
# 230             3,628            NaN            NaN           NaN
#
#         Population          Continent
# 0    1,448,471,400               Asia
# 1      334,805,269      North America
# 2    1,406,631,776               Asia
# 3       65,584,518             Europe
# 4       83,883,596             Europe
# ..             ...                ...
# 226            NaN                NaN
# 227            799             Europe
# 228        626,161             Africa
# 229            NaN                NaN
# 230          1,378  Australia/Oceania
#
# [231 rows x 15 columns]

# %% [markdown]
# ### Insert `Date` column into dataframe

# %%
Date22 = ('22/02/2023')
Date23 = ('23/02/2023')
Date24 = ('24/02/2023')
dfDate22['Date'] = Date22
dfDate23['Date'] = Date23
dfDate24['Date'] = Date24

# %%
dfDate24.head(10)
# Out:
#   Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# 0            USA  105,161,023       NaN    1,144,368         NaN
# 1          India   44,685,619       NaN      530,764         NaN
# 2         France   39,605,037       NaN      164,848         NaN
# 3        Germany   38,090,089       NaN      167,723         NaN
# 4         Brazil   37,008,944       NaN      698,834         NaN
# 5          Japan   33,157,721    +6,512       72,134        83.0
# 6       S. Korea   30,479,753   +10,051       33,929        20.0
# 7          Italy   25,547,414       NaN      187,850         NaN
# 8             UK   24,341,615       NaN      206,246         NaN
# 9         Russia   22,232,492   +13,829      395,970        32.0
#
#   Total Recovered New Recovered Active Cases Serious, Critical  \
# 0     102,534,080           NaN    1,482,575             2,425
# 1      44,152,839           NaN        2,016               NaN
# 2      39,371,608           NaN       68,581               869
# 3      37,654,800           NaN      267,566               NaN
# 4      36,179,646           NaN      130,464               NaN
# 5      21,675,630        +2,474   11,409,957               183
# 6      30,229,352        +5,828      216,472               183
# 7      25,174,036           NaN      185,528               154
# 8      24,076,386        +2,442       58,983               NaN
# 9      21,570,255       +12,618      266,267               NaN
#
#   Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0           314,096          3,418  1,163,861,047     3,476,233
# 1            31,768            377    918,216,867       652,777
# 2           603,878          2,514    271,490,188     4,139,547
# 3           454,083          1,999    122,332,384     1,458,359
# 4           171,852          3,245     63,776,166       296,146
# 5           264,026            574     94,827,129       755,084
# 6           593,801            661     15,804,065       307,892
# 7           423,934          3,117    267,156,892     4,433,200
# 8           355,363          3,011    522,526,476     7,628,357
# 9           152,480          2,716    273,400,000     1,875,095
#
#       Population      Continent        Date
# 0    334,805,269  North America  24/02/2023
# 1  1,406,631,776           Asia  24/02/2023
# 2     65,584,518         Europe  24/02/2023
# 3     83,883,596         Europe  24/02/2023
# 4    215,353,593  South America  24/02/2023
# 5    125,584,838           Asia  24/02/2023
# 6     51,329,899           Asia  24/02/2023
# 7     60,262,770         Europe  24/02/2023
# 8     68,497,907         Europe  24/02/2023
# 9    145,805,947         Europe  24/02/2023

# %% [markdown]
# ### Join 3 dataframes of 3-days

# %%
frames = [dfDate22, dfDate23, dfDate24]
df = pd.concat(frames, ignore_index = True)
df
# Out:
#      Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# 0             China      503,302       NaN        5,272         NaN
# 1               USA  105,148,929   +24,941    1,144,242       249.0
# 2             India   44,685,450      +193      530,763         1.0
# 3            France   39,600,548    +4,584      164,829        38.0
# 4           Germany   38,068,912   +25,038      167,604       113.0
# ..              ...          ...       ...          ...         ...
# 688    Vatican City           29       NaN          NaN         NaN
# 689  Western Sahara           10       NaN            1         NaN
# 690      MS Zaandam            9       NaN            2         NaN
# 691         Tokelau            5       NaN          NaN         NaN
# 692           China      503,302       NaN        5,272         NaN
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0           379,053           NaN      118,977             7,557
# 1       102,473,264       +58,247    1,531,423             2,436
# 2        44,152,687          +127        2,000               NaN
# 3        39,368,047        +3,989       67,672               869
# 4        37,630,800       +13,600      270,508               NaN
# ..              ...           ...          ...               ...
# 688              29           NaN            0               NaN
# 689               9           NaN            0               NaN
# 690               7           NaN            0               NaN
# 691             NaN           NaN            5               NaN
# 692         379,053           NaN      118,977               NaN
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0                 347              4    160,000,000       110,461
# 1             314,060          3,418  1,163,631,220     3,475,546
# 2              31,768            377    918,101,478       652,695
# 3             603,809          2,513    271,490,188     4,139,547
# 4             453,830          1,998    122,332,384     1,458,359
# ..                ...            ...            ...           ...
# 688            36,295            NaN            NaN           NaN
# 689                16              2            NaN           NaN
# 690               NaN            NaN            NaN           NaN
# 691             3,628            NaN            NaN           NaN
# 692               347              4    160,000,000       110,461
#
#         Population          Continent        Date
# 0    1,448,471,400               Asia  22/02/2023
# 1      334,805,269      North America  22/02/2023
# 2    1,406,631,776               Asia  22/02/2023
# 3       65,584,518             Europe  22/02/2023
# 4       83,883,596             Europe  22/02/2023
# ..             ...                ...         ...
# 688            799             Europe  24/02/2023
# 689        626,161             Africa  24/02/2023
# 690            NaN                NaN  24/02/2023
# 691          1,378  Australia/Oceania  24/02/2023
# 692  1,448,471,400               Asia  24/02/2023
#
# [693 rows x 16 columns]

# %% [markdown]
# ### Convert `Date` from string to datetime

# %%
df['Date'] = pd.to_datetime(df['Date'], yearfirst = False)
df['Date'].dt.day.unique()
# Out:
# array([22, 23, 24])

# %% [markdown]
# ### Swap `Date` column order to the first

# %%
df = df[['Date'] + [ col for col in df.columns if col != 'Date' ]]
df
# Out:
#            Date  Country, Other  Total Cases New Cases Total Deaths  \
# 0    22/02/2023           China      503,302       NaN        5,272
# 1    22/02/2023             USA  105,148,929   +24,941    1,144,242
# 2    22/02/2023           India   44,685,450      +193      530,763
# 3    22/02/2023          France   39,600,548    +4,584      164,829
# 4    22/02/2023         Germany   38,068,912   +25,038      167,604
# ..          ...             ...          ...       ...          ...
# 688  24/02/2023    Vatican City           29       NaN          NaN
# 689  24/02/2023  Western Sahara           10       NaN            1
# 690  24/02/2023      MS Zaandam            9       NaN            2
# 691  24/02/2023         Tokelau            5       NaN          NaN
# 692  24/02/2023           China      503,302       NaN        5,272
#
#      New Deaths Total Recovered New Recovered Active Cases Serious, Critical  \
# 0           NaN         379,053           NaN      118,977             7,557
# 1         249.0     102,473,264       +58,247    1,531,423             2,436
# 2           1.0      44,152,687          +127        2,000               NaN
# 3          38.0      39,368,047        +3,989       67,672               869
# 4         113.0      37,630,800       +13,600      270,508               NaN
# ..          ...             ...           ...          ...               ...
# 688         NaN              29           NaN            0               NaN
# 689         NaN               9           NaN            0               NaN
# 690         NaN               7           NaN            0               NaN
# 691         NaN             NaN           NaN            5               NaN
# 692         NaN         379,053           NaN      118,977               NaN
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0                 347              4    160,000,000       110,461
# 1             314,060          3,418  1,163,631,220     3,475,546
# 2              31,768            377    918,101,478       652,695
# 3             603,809          2,513    271,490,188     4,139,547
# 4             453,830          1,998    122,332,384     1,458,359
# ..                ...            ...            ...           ...
# 688            36,295            NaN            NaN           NaN
# 689                16              2            NaN           NaN
# 690               NaN            NaN            NaN           NaN
# 691             3,628            NaN            NaN           NaN
# 692               347              4    160,000,000       110,461
#
#         Population          Continent
# 0    1,448,471,400               Asia
# 1      334,805,269      North America
# 2    1,406,631,776               Asia
# 3       65,584,518             Europe
# 4       83,883,596             Europe
# ..             ...                ...
# 688            799             Europe
# 689        626,161             Africa
# 690            NaN                NaN
# 691          1,378  Australia/Oceania
# 692  1,448,471,400               Asia
#
# [693 rows x 16 columns]

# %%
df.keys()
# Out:
# Index(['Date', 'Country, Other', 'Total Cases', 'New Cases', 'Total Deaths',
#        'New Deaths', 'Total Recovered', 'New Recovered', 'Active Cases',
#        'Serious, Critical', 'Tot Cases/ 1M pop', 'Deaths/ 1M pop',
#        'Total Tests', 'Tests/ 1M pop', 'Population', 'Continent'],
#       dtype='object')

# %% [markdown]
# # Data explorations
# ## How many rows and columns does the data have ?

# %%
Num_rows,Num_cols=df.shape
print(f"The data have {Num_rows} rowls")
print(f"The data have {Num_cols} columns")
# Out:
# The data have 231 rowls
# The data have 15 columns

# %% [markdown]
# ## Are there any dulicate rows in the data?

# %%
have_duplicate_rows = df.duplicated().sum()
print("Yes duplicate") if have_duplicate_rows else print('No duplicate')
# Out:
# No duplicate

# %% [markdown]
# ## What do the columns in the data mean?

# %% [markdown]
# **Country, Other** : Name of the country, or place.
#
# **Total Cases** : Total cases get covid.
#
# **New Cases** : New cases get covid today.
#
# **Total Deaths** : Total cases deaths.
#
# **New Deaths** : New cases get death by covid.
#
# **Total Recovered** : Total recovered from covid.
#
# **New Recovered** : New cases recovered from covid today.
#
# **Active Cases** : Active cases today.
#
# **Serious, Critical** : Serious, Critical cases.
#
# **Tot Cases/ 1M pop** : Total cases get covid per 1 million populations.
#
# **Deaths/ 1M pop** : Total cases deaths by covid per 1 million populations.
#
# **Total Tests** : Total test cases.
#
# **Tests/ 1M pop** : Total test cases per 1 million population.
#
# **Population** : population.
#
# **Continent** : continent name.

# %%
dfDate22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         231 non-null    int64
#  1   Country, Other     231 non-null    object
#  2   Total Cases        231 non-null    object
#  3   New Cases          86 non-null     object
#  4   Total Deaths       225 non-null    object
#  5   New Deaths         37 non-null     float64
#  6   Total Recovered    210 non-null    object
#  7   New Recovered      67 non-null     object
#  8   Active Cases       212 non-null    object
#  9   Serious, Critical  124 non-null    object
#  10  Tot Cases/ 1M pop  229 non-null    object
#  11  Deaths/ 1M pop     223 non-null    object
#  12  Total Tests        213 non-null    object
#  13  Tests/ 1M pop      213 non-null    object
#  14  Population         229 non-null    object
#  15  Continent          229 non-null    object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 29.0+ KB

# %% [markdown]
# **What does columns that have object type mean?**
#
# All columns in data have datatype of object expect New Deaths. If the datatype of a column in dataframe is object, the datatype of elements in that column can be different from each other. so we will list the data types present in each colum

# %%
def check_dtype(col_name):
    s = dfDate22[col_name]
    dtypes = set()
    s.apply(lambda x : dtypes.add(type(x)))
    print(f'List type in {col_name} column: {dtypes}')
    return dtypes

for col_name in dfDate22.columns:
    check_dtype(col_name)
# Out:
# List type in Country, Other column: {<class 'str'>}
# List type in Total Cases column: {<class 'str'>}
# List type in New Cases column: {<class 'str'>, <class 'float'>}
# List type in Total Deaths column: {<class 'str'>, <class 'float'>}
# List type in New Deaths column: {<class 'float'>}
# List type in Total Recovered column: {<class 'str'>, <class 'float'>}
# List type in New Recovered column: {<class 'str'>, <class 'float'>}
# List type in Active Cases column: {<class 'str'>, <class 'float'>}
# List type in Serious, Critical column: {<class 'str'>, <class 'float'>}
# List type in Tot Cases/ 1M pop column: {<class 'str'>, <class 'float'>}
# List type in Deaths/ 1M pop column: {<class 'str'>, <class 'float'>}
# List type in Total Tests column: {<class 'str'>, <class 'float'>}
# List type in Tests/ 1M pop column: {<class 'str'>, <class 'float'>}
# List type in Population column: {<class 'str'>, <class 'float'>}
# List type in Continent column: {<class 'str'>, <class 'float'>}

# %% [markdown]
# #### Issues that need to be reprocessed:

# %% [markdown]
# * Replace NaN to 0 in which columns has types is float expect the column 'Continent'

# %%
df['Continent']=df['Continent'].fillna('Do not know')
dfDate22=dfDate22.fillna(0)
dfDate22
# Out:
#        Country, Other  Total Cases New Cases Total Deaths  New Deaths  \
# 0               China      503,302         0        5,272         0.0
# 1                 USA  105,148,929   +24,941    1,144,242       249.0
# 2               India   44,685,450      +193      530,763         1.0
# 3              France   39,600,548    +4,584      164,829        38.0
# 4             Germany   38,068,912   +25,038      167,604       113.0
# ..                ...          ...       ...          ...         ...
# 226  Diamond Princess          712         0           13         0.0
# 227      Vatican City           29         0            0         0.0
# 228    Western Sahara           10         0            1         0.0
# 229        MS Zaandam            9         0            2         0.0
# 230           Tokelau            5         0            0         0.0
#
#     Total Recovered New Recovered Active Cases Serious, Critical  \
# 0           379,053             0      118,977             7,557
# 1       102,473,264       +58,247    1,531,423             2,436
# 2        44,152,687          +127        2,000                 0
# 3        39,368,047        +3,989       67,672               869
# 4        37,630,800       +13,600      270,508                 0
# ..              ...           ...          ...               ...
# 226             699             0            0                 0
# 227              29             0            0                 0
# 228               9             0            0                 0
# 229               7             0            0                 0
# 230               0             0            5                 0
#
#     Tot Cases/ 1M pop Deaths/ 1M pop    Total Tests Tests/ 1M pop  \
# 0                 347              4    160,000,000       110,461
# 1             314,060          3,418  1,163,631,220     3,475,546
# 2              31,768            377    918,101,478       652,695
# 3             603,809          2,513    271,490,188     4,139,547
# 4             453,830          1,998    122,332,384     1,458,359
# ..                ...            ...            ...           ...
# 226                 0              0              0             0
# 227            36,295              0              0             0
# 228                16              2              0             0
# 229                 0              0              0             0
# 230             3,628              0              0             0
#
#         Population          Continent
# 0    1,448,471,400               Asia
# 1      334,805,269      North America
# 2    1,406,631,776               Asia
# 3       65,584,518             Europe
# 4       83,883,596             Europe
# ..             ...                ...
# 226              0        Do not know
# 227            799             Europe
# 228        626,161             Africa
# 229              0        Do not know
# 230          1,378  Australia/Oceania
#
# [231 rows x 15 columns]

# %% [markdown]
# #### Convert all the data into int

# %% [markdown]
# ##### Get column with float type to convert to string

# %%
convert_columns = dfDate22.columns.tolist()
convert_columns=convert_columns[1:-1]
# convert_columns.remove('Total Deaths')
# convert_columns.remove('New Cases')
convert_columns.remove('New Deaths')
# convert_columns.remove('New Recovered')
convert_columns
# Out:
# ['Total Cases',
#  'New Cases',
#  'Total Deaths',
#  'Total Recovered',
#  'New Recovered',
#  'Active Cases',
#  'Serious, Critical',
#  'Tot Cases/ 1M pop',
#  'Deaths/ 1M pop',
#  'Total Tests',
#  'Tests/ 1M pop',
#  'Population']

# %%
for col in convert_columns:
    dfDate22[col]=dfDate22[col].astype(str).apply(lambda x: x.replace(",",''))
    dfDate22[col]=dfDate22[col].apply(lambda x:int(x))

dfDate22
# Out:
#        Country, Other  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0               China       503302          0          5272         0.0
# 1                 USA    105148929      24941       1144242       249.0
# 2               India     44685450        193        530763         1.0
# 3              France     39600548       4584        164829        38.0
# 4             Germany     38068912      25038        167604       113.0
# ..                ...          ...        ...           ...         ...
# 226  Diamond Princess          712          0            13         0.0
# 227      Vatican City           29          0             0         0.0
# 228    Western Sahara           10          0             1         0.0
# 229        MS Zaandam            9          0             2         0.0
# 230           Tokelau            5          0             0         0.0
#
#      Total Recovered  New Recovered  Active Cases  Serious, Critical  \
# 0             379053              0        118977               7557
# 1          102473264          58247       1531423               2436
# 2           44152687            127          2000                  0
# 3           39368047           3989         67672                869
# 4           37630800          13600        270508                  0
# ..               ...            ...           ...                ...
# 226              699              0             0                  0
# 227               29              0             0                  0
# 228                9              0             0                  0
# 229                7              0             0                  0
# 230                0              0             5                  0
#
#      Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  Tests/ 1M pop  \
# 0                  347               4    160000000         110461
# 1               314060            3418   1163631220        3475546
# 2                31768             377    918101478         652695
# 3               603809            2513    271490188        4139547
# 4               453830            1998    122332384        1458359
# ..                 ...             ...          ...            ...
# 226                  0               0            0              0
# 227              36295               0            0              0
# 228                 16               2            0              0
# 229                  0               0            0              0
# 230               3628               0            0              0
#
#      Population          Continent
# 0    1448471400               Asia
# 1     334805269      North America
# 2    1406631776               Asia
# 3      65584518             Europe
# 4      83883596             Europe
# ..          ...                ...
# 226           0        Do not know
# 227         799             Europe
# 228      626161             Africa
# 229           0        Do not know
# 230        1378  Australia/Oceania
#
# [231 rows x 15 columns]

# %%
# dfDate22['New Deaths']=dfDate22['New Deaths'].str.slice(stop=-2).astype(int)
dfDate22.dtypes
# Out:
# Country, Other        object
# Total Cases            int64
# New Cases              int64
# Total Deaths           int64
# New Deaths           float64
# Total Recovered        int64
# New Recovered          int64
# Active Cases           int64
# Serious, Critical      int64
# Tot Cases/ 1M pop      int64
# Deaths/ 1M pop         int64
# Total Tests            int64
# Tests/ 1M pop          int64
# Population             int64
# Continent             object
# dtype: object

# %% [markdown]
# #### Write to file output

# %%
dfDate22.to_csv('output.csv', index=True)
